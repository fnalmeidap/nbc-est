# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="darkgrid")
sns.color_palette("flare", as_cmap=True)
PORT_DIR = '../data/student-por.csv'

# %%
port_df = pd.read_csv(PORT_DIR, sep=';')
port_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
mat_df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
mat_df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
sns.catplot(x="sex", kind="count", data = mat_df,palette="flare")

# %%
sns.catplot(x="age", kind="count", data = mat_df, aspect=2,palette="flare")

# %%
sns.catplot(x="famsize", kind="count", data = mat_df,palette="flare")

# %%
sns.catplot(x="Pstatus", kind="count", data = mat_df,palette="flare")

# %%
pedu = mat_df[['Medu','Fedu']]

plt.figure(figsize=(20,10))
sns.histplot(data=pedu)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
pjob = mat_df[['Mjob','Fjob']]
plt.hist(pjob["Mjob"], alpha=0.5, label='Mães')
plt.hist(pjob["Fjob"], alpha=0.5, label='Pais')
plt.legend(loc='upper right')
plt.show()

# %%
sns.catplot(x="guardian", kind="count", data = mat_df,palette="flare")

# %%
sns.catplot(x="studytime", kind="count", data = mat_df,palette="flare")

# %%
sns.catplot(x="schoolsup", kind="count", data = mat_df,palette="flare")

# %%
sns.catplot(x="activities", kind="count", data = mat_df,palette="flare")

# %%
sns.catplot(x="higher", kind="count", data = mat_df,palette="flare")

# %%
sns.catplot(x="internet", kind="count", data = mat_df,palette="flare")

# %%
sns.catplot(x="romantic", kind="count", data = mat_df,palette="flare")

# %%
sns.catplot(x="famrel", kind="count", data = mat_df,palette="flare")

# %%
sns.catplot(x="freetime", kind="count", data = mat_df,palette="flare")

# %%
sns.catplot(x="goout", kind="count", data = mat_df,palette="flare")

# %%
sns.catplot(x="Dalc", kind="count", data = mat_df,palette="flare")
sns.catplot(x="Walc", kind="count", data = mat_df,palette="flare")

# %%
sns.catplot(x="absences", kind="count", data = mat_df,palette="flare",aspect=2)

# %%
data = mat_df[['G1','G2','G3']]
plt.figure(figsize=(15,8))
sns.violinplot(data=data, palette="light:g", inner="points", orient="h")
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x="G1", y="age", data=mat_df)
sns.jointplot(x="G2", y="age", data=mat_df, color='green')
sns.jointplot(x="G3", y="age", data=mat_df, color='red')
